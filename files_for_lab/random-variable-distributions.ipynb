# %%
1#Use the numerical variables from our dataset this week.

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

numerical_df = pd.read_csv('numerical.csv')

# %%
numerical_df
# Out:
#       customer_lifetime_value   income  monthly_premium_auto  \
# 0                 2763.519279  56274.0                    69
# 1                 6979.535903      0.0                    94
# 2                12887.431650  48767.0                   108
# 3                 7645.861827      0.0                   106
# 4                 2813.692575  43836.0                    73
# ...                       ...      ...                   ...
# 9129             23405.987980  71941.0                    73
# 9130              3096.511217  21604.0                    79
# 9131              8163.890428      0.0                    85
# 9132              7524.442436  21941.0                    96
# 9133              2611.836866      0.0                    77
#
#       months_since_last_claim  months_since_policy_inception  \
# 0                          32                              5
# 1                          13                             42
# ...

# %%
#2. Check using a distribution plot if the variables fit the theoretical normal or exponential distribution.

#iteration code to check if the columns in numerical_df have a normal or exponential distribution

for column in numerical_df.columns:
    plt.figure(figsize=(8, 4))
    sns.histplot(numerical_df[column], kde=True)
    plt.title(f'Distribution of {column}')
    plt.xlabel(column)
    plt.ylabel('Frequency')
    plt.show()

# %%
# 3.The bell shape indicating a perfect normal distribution isn't verified in any of the plots, 
#except maybe a little for total_claim_amount

# %%
import numpy as np

transformlog_variable = np.log(numerical_df)
transformlog_variable
# Out:
# C:\Users\Startklar\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:351: RuntimeWarning: divide by zero encountered in log
#   result = func(self.values, **kwargs)
#       customer_lifetime_value     income  monthly_premium_auto  \
# 0                    7.924260  10.937988              4.234107
# 1                    8.850738       -inf              4.543295
# 2                    9.464008  10.794809              4.682131
# 3                    8.941920       -inf              4.663439
# 4                    7.942253  10.688211              4.290459
# ...                       ...        ...                   ...
# 9129                10.060747  11.183602              4.290459
# 9130                 8.038031   9.980634              4.369448
# 9131                 9.007476       -inf              4.442651
# 9132                 8.925912   9.996112              4.564348
# 9133                 7.867809       -inf              4.343805
#
# ...

# %%
#Applying plotting on logged transformed columns in categorical_df

for column in numerical_df.columns:
    plt.figure(figsize=(8, 4))
    sns.histplot(transformlog_variable[column], kde=True)
    plt.title(f'Distribution of {column}')
    plt.xlabel(column)
    plt.ylabel('Frequency')
    plt.show()
