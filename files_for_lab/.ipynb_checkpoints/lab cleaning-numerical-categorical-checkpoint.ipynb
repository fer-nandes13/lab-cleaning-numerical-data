# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
customer_df = pd.read_csv('we_fn_use_c_marketing_customer_value_analysis.csv')
customer_df
# Out:
#      Customer       State  Customer Lifetime Value Response  Coverage  \
# 0     BU79786  Washington              2763.519279       No     Basic
# 1     QZ44356     Arizona              6979.535903       No  Extended
# 2     AI49188      Nevada             12887.431650       No   Premium
# 3     WW63253  California              7645.861827       No     Basic
# 4     HB64268  Washington              2813.692575       No     Basic
# ...       ...         ...                      ...      ...       ...
# 9129  LA72316  California             23405.987980       No     Basic
# 9130  PK87824  California              3096.511217      Yes  Extended
# 9131  TD14365  California              8163.890428       No  Extended
# 9132  UP19263  California              7524.442436       No  Extended
# 9133  Y167826  California              2611.836866       No  Extended
#
#      Education Effective To Date EmploymentStatus Gender  Income  ...  \
# ...

# %%
pd.set_option('display.max_columns', None)

# %%
cols = []
for column in customer_df.columns:
    cols.append(column.lower())
cols
customer_df.columns = cols

# %%
customer_df
# Out:
#      customer       state  customer lifetime value response  coverage  \
# 0     BU79786  Washington              2763.519279       No     Basic
# 1     QZ44356     Arizona              6979.535903       No  Extended
# 2     AI49188      Nevada             12887.431650       No   Premium
# 3     WW63253  California              7645.861827       No     Basic
# 4     HB64268  Washington              2813.692575       No     Basic
# ...       ...         ...                      ...      ...       ...
# 9129  LA72316  California             23405.987980       No     Basic
# 9130  PK87824  California              3096.511217      Yes  Extended
# 9131  TD14365  California              8163.890428       No  Extended
# 9132  UP19263  California              7524.442436       No  Extended
# 9133  Y167826  California              2611.836866       No  Extended
#
#      education effective to date employmentstatus gender  income  \
# ...

# %%
converter = lambda x: x.replace(' ', '_')
col_low= customer_df.columns
col_low = list(map(converter, col_low))
customer_df.columns = col_low
customer_df
# Out:
#      customer       state  customer_lifetime_value response  coverage  \
# 0     BU79786  Washington              2763.519279       No     Basic
# 1     QZ44356     Arizona              6979.535903       No  Extended
# 2     AI49188      Nevada             12887.431650       No   Premium
# 3     WW63253  California              7645.861827       No     Basic
# 4     HB64268  Washington              2813.692575       No     Basic
# ...       ...         ...                      ...      ...       ...
# 9129  LA72316  California             23405.987980       No     Basic
# 9130  PK87824  California              3096.511217      Yes  Extended
# 9131  TD14365  California              8163.890428       No  Extended
# 9132  UP19263  California              7524.442436       No  Extended
# 9133  Y167826  California              2611.836866       No  Extended
#
#      education effective_to_date employmentstatus gender  income  \
# ...

# %%
customer_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9134 entries, 0 to 9133
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   customer                       9134 non-null   object
#  1   state                          9134 non-null   object
#  2   customer_lifetime_value        9134 non-null   float64
#  3   response                       9134 non-null   object
#  4   coverage                       9134 non-null   object
#  5   education                      9134 non-null   object
#  6   effective_to_date              9134 non-null   object
#  7   employmentstatus               9134 non-null   object
#  8   gender                         9134 non-null   object
#  9   income                         9134 non-null   int64
#  10  location_code                  9134 non-null   object
#  11  marital_status                 9134 non-null   object
# ...

# %%
import pandas as pd

# Convert the "effective_to_date" column to datetime
customer_df['effective_to_date'] = pd.to_datetime(customer_df['effective_to_date'])

# Now, the "effective_to_date" column is of type datetime64
# You can access it like any other datetime column

# %%
customer_df.dtypes
# Out:
# customer                                 object
# state                                    object
# customer_lifetime_value                 float64
# response                                 object
# coverage                                 object
# education                                object
# effective_to_date                datetime64[ns]
# employmentstatus                         object
# gender                                   object
# income                                    int64
# location_code                            object
# marital_status                           object
# monthly_premium_auto                      int64
# months_since_last_claim                   int64
# months_since_policy_inception             int64
# number_of_open_complaints                 int64
# number_of_policies                        int64
# policy_type                              object
# policy                                   object
# renew_offer_type                         object
# ...

# %%
# Retrieve unique values for the specified columns
unique_monthly_premium_auto = customer_df['monthly_premium_auto'].unique()
unique_number_of_policies = customer_df['number_of_policies'].unique()
unique_total_claim_amount = customer_df['number_of_open_complaints'].unique()

# Print unique values for each column
print("Unique values in 'monthly_premium_auto':", unique_monthly_premium_auto)
print("Unique values in 'number_of_policies':", unique_number_of_policies)
print("Unique values in 'number_of_open_complaints':", unique_total_claim_amount)
# Out:
# Unique values in 'monthly_premium_auto': [ 69  94 108 106  73  67 101  71  93 110  70  64  72  74  79  61 111 139
#   80  63 237  65  62 117  91  90  66  99 103 172  92 104 113 124 105 100
#  112  97  95 102 186  77  96  76 119  88 109 107 130  85  98 133  86  78
#   83  68 192 118  89 140 127 168 126  82 115 217 114 138  81 255 150 123
#  116 190 159  84 152 136 245 135 128 225 132 153 121 154 161 156 171  87
#  244 183 176 230 129 177 196 131 276 253 137 180 203 147 165 198 125 193
#  271 188 142 206 182 189 160 295 210 134 239 256 173 285 148 197 199 214
#  175 167 194 164 181 222 215 283 169 248 223 273 151 213 145 185 287 297
#  201 149 146 235 268 211 187 141 242 170 122 143 155 166 212 249 240 191
#  195 216 144 179 232 158 207 184 238 229 220 178 204 281 234 218 275 209
#  261 157 205 228 284 231 208 296 202 162 274 219 247 290 226 163 298 266
#  254 252 174 286]
# Unique values in 'number_of_policies': [1 8 2 7 9 4 3 6 5]
# ...

# %%
# Retrieve unique values for the "income" column
unique_income_values = customer_df['income'].unique()

# Print unique values for the "income" column
print("Unique values in 'income':", unique_income_values)
# Out:
# Unique values in 'income': [56274     0 48767 ... 66367 71941 21941]

# %%
# Retrieve the count of unique values for the "income" column
unique_income_count = customer_df['income'].nunique()

# Print the count of unique values for the "income" column
print("Count of unique values in 'income':", unique_income_count)
# Out:
# Count of unique values in 'income': 5694

# %%
def value_count(customer_df):
    for column in customer_df.columns:
        print(column, ':', len(customer_df[column].value_counts()))

# Call the function to count unique values for each column in customer_df
value_count(customer_df)
# Out:
# customer : 9134
# state : 5
# customer_lifetime_value : 8041
# response : 2
# coverage : 3
# education : 5
# effective_to_date : 59
# employmentstatus : 5
# gender : 2
# income : 5694
# location_code : 3
# marital_status : 3
# monthly_premium_auto : 202
# months_since_last_claim : 36
# months_since_policy_inception : 100
# number_of_open_complaints : 6
# number_of_policies : 9
# policy_type : 3
# policy : 9
# renew_offer_type : 4
# sales_channel : 4
# total_claim_amount : 5106
# vehicle_class : 6
# vehicle_size : 3

# %%
# Convert the "income" column to float64 because the income does not fall into a range or set of values countable, 
#there is no pattern
customer_df['income'] = customer_df['income'].astype(float)

# Now, the "income" column is of type float6

# %%
# Create a new DataFrame containing only numerical columns
numerical_df = customer_df.select_dtypes(include=['number'])
numerical_df
# Now, the numerical_df contains only the numerical columns from customer_df
# Out:
#       customer_lifetime_value   income  monthly_premium_auto  \
# 0                 2763.519279  56274.0                    69
# 1                 6979.535903      0.0                    94
# 2                12887.431650  48767.0                   108
# 3                 7645.861827      0.0                   106
# 4                 2813.692575  43836.0                    73
# ...                       ...      ...                   ...
# 9129             23405.987980  71941.0                    73
# 9130              3096.511217  21604.0                    79
# 9131              8163.890428      0.0                    85
# 9132              7524.442436  21941.0                    96
# 9133              2611.836866      0.0                    77
#
#       months_since_last_claim  months_since_policy_inception  \
# 0                          32                              5
# 1                          13                             42
# ...

# %%
def differentiate_numerical_types(df):
    # Select numerical columns of type float64
    continuous_df = df.select_dtypes(include=['float64'])
    
    # Select numerical columns of type int64
    discrete_df = df.select_dtypes(include=['int64'])
    
    return continuous_df, discrete_df

# Call the function to get continuous and discrete variables
continuous_df, discrete_df = differentiate_numerical_types(customer_df)

# Now, continuous_df contains float64 columns, and discrete_df contains int64 columns

# %%
discrete_df
# keeping  the columns below as discrete values since the range of values fall into a set or range that is countable
# for example the monthly_premium_auto with 202 possible values has a range that starts with a min of 69 and ends up with a max of
#298
# Out:
#       monthly_premium_auto  months_since_last_claim  \
# 0                       69                       32
# 1                       94                       13
# 2                      108                       18
# 3                      106                       18
# 4                       73                       12
# ...                    ...                      ...
# 9129                    73                       18
# 9130                    79                       14
# 9131                    85                        9
# 9132                    96                       34
# 9133                    77                        3
#
#       months_since_policy_inception  number_of_open_complaints  \
# 0                                 5                          0
# 1                                42                          0
# 2                                38                          0
# 3                                65                          0
# ...

# %%
continuous_df
# Out:
#       customer_lifetime_value   income  total_claim_amount
# 0                 2763.519279  56274.0          384.811147
# 1                 6979.535903      0.0         1131.464935
# 2                12887.431650  48767.0          566.472247
# 3                 7645.861827      0.0          529.881344
# 4                 2813.692575  43836.0          138.130879
# ...                       ...      ...                 ...
# 9129             23405.987980  71941.0          198.234764
# 9130              3096.511217  21604.0          379.200000
# 9131              8163.890428      0.0          790.784983
# 9132              7524.442436  21941.0          691.200000
# 9133              2611.836866      0.0          369.600000
#
# [9134 rows x 3 columns]

# %%
correlations_matrix = numerical_df.corr()
sns.heatmap(correlations_matrix, annot=True)
plt.show()

# %%
#Strongest positive correlation is between monthly premium auto and the target total_claim amount with 0.63. In spite of being the 
# strongest that does not bring us to the urgency of dropping 
#Strongeste negative correlation is between income and total claim amount which means that total claim amount may not have nothing
# to do with the amount of income of the customers

# %%
#Create a function to plot every discrete variable. Do the same with the continuous variables

# %%
def plot_discrete_variables(df):
    # Iterate through columns in the DataFrame
    for column in discrete_df.columns:
        # Check if the column is discrete (e.g., int or categorical)
        if discrete_df[column].dtype in [int, 'int64', 'int32']:
            # Create a count plot (bar plot) for the discrete variable
            plt.figure(figsize=(8, 6))
            sns.histplot(data=df, x=column)
            plt.title(f'Distribution of {column}')
            plt.xlabel(column)
            plt.ylabel('Count')
            plt.xticks(rotation=45)
            plt.show()

# Call the function to plot discrete variables in the "discrete_df" DataFrame
plot_discrete_variables(discrete_df)

# %%
#Create a function to plot every discrete variable. Do the same with the continuous variables 

def plot_discrete_variables_boxplot(df):
    # Iterate through columns in the DataFrame
    for column in df.columns:
        # Check if the column is discrete (e.g., int or categorical)
        if df[column].dtype in [int, 'int64', 'int32']:
            # Create a box plot for the discrete variable
            plt.figure(figsize=(8, 6))
            sns.boxplot(data=df, x=column)
            plt.title(f'Box Plot of {column}')
            plt.xlabel(column)
            plt.show()

# Call the function to plot discrete variables using box plots in the "discrete_df" DataFrame
plot_discrete_variables_boxplot(discrete_df)

# %%
def plot_continuous_variables(df):
    # Iterate through columns in the DataFrame
    for column in df.columns:
        # Check if the column is continuous (e.g., float)
        if df[column].dtype in [float, 'float64', 'float32']:
            # Create a distribution plot (histogram) for the continuous variable
            plt.figure(figsize=(8, 6))
            sns.histplot(data=df, x=column, kde=True)
            plt.title(f'Distribution of {column}')
            plt.xlabel(column)
            plt.ylabel('Density')
            plt.show()

# Call the function to plot continuous variables in the "continuous_df" DataFrame
plot_continuous_variables(continuous_df)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

def plot_continuous_variables_boxplot(df):
    # Iterate through columns in the DataFrame
    for column in df.columns:
        # Check if the column is continuous (e.g., float)
        if df[column].dtype in [float, 'float64', 'float32']:
            # Create a box plot for the continuous variable
            plt.figure(figsize=(8, 6))
            sns.boxplot(data=df, x=column)
            plt.title(f'Box Plot of {column}')
            plt.xlabel(column)
            plt.show()

# Call the function to plot continuous variables using box plots in the "continuous_df" DataFrame
plot_continuous_variables_boxplot(continuous_df)

# %%
#Comment what you can see in the plots.

#Based on the plots above we can see for the continuous data variables except (income) not so much of a normal distribution, with most of the 
#values skewed to the left.

#In the discrete data variables the monthly_premium_auto has a more deep skew to left indicating not so much of a normal distribution.
# In the cases that we are able to see from the plots that the distributions are not normalized a log transform could be an approach.

# %%
#Look for outliers in the continuous variables

# %%
def find_outliers_iqr(df, factor=1.5):
    # Calculating the first quartile (Q1) and third quartile (Q3) for each column
    Q1 = df.quantile(0.25)
    Q3 = df.quantile(0.75)
    
    # Calculating the IQR (Interquartile Range) for each column
    IQR = Q3 - Q1
    
    # Defining the lower and upper bounds for identifying outliers
    lower_bound = Q1 - factor * IQR
    upper_bound = Q3 + factor * IQR
    
    # Finding outliers by comparing values to the bounds
    outliers = ((df < lower_bound) | (df > upper_bound))
    
    # Count the number of outliers in each column
    outlier_count = outliers.sum()
    
    outlier_info = pd.DataFrame({'Variable': outlier_count.index, 'Outlier Count': outlier_count.values})
    
    return outliers, outlier_info

# Set the IQR factor for outlier detection (default is 1.5)
iqr_factor = 1.5

# Find outliers in the continuous_df DataFrame and get outlier counts
outliers, outlier_info = find_outliers_iqr(continuous_df, factor=iqr_factor)

# Display the DataFrame of outliers (True indicates an outlier)
print("Outliers:")
print(outliers)

# Display the DataFrame with outlier counts
print("\nOutlier Counts:")
outlier_info
# Out:
# Outliers:
#       customer_lifetime_value  income  total_claim_amount
# 0                       False   False               False
# 1                       False   False                True
# 2                       False   False               False
# 3                       False   False               False
# 4                       False   False               False
# ...                       ...     ...                 ...
# 9129                     True   False               False
# 9130                    False   False               False
# 9131                    False   False               False
# 9132                    False   False               False
# 9133                    False   False               False
#
# [9134 rows x 3 columns]
#
# Outlier Counts:
#                   Variable  Outlier Count
# 0  customer_lifetime_value            817
# 1                   income              0
# 2       total_claim_amount            453

# %%
outliers, outlier_info = find_outliers_iqr(discrete_df, factor=iqr_factor)

# Display the DataFrame of outliers (True indicates an outlier)
print("Outliers:")
print(outliers)

# Display the DataFrame with outlier counts
print("\nOutlier Counts:")
outlier_info
# Out:
# Outliers:
#       monthly_premium_auto  months_since_last_claim  \
# 0                    False                    False
# 1                    False                    False
# 2                    False                    False
# 3                    False                    False
# 4                    False                    False
# ...                    ...                      ...
# 9129                 False                    False
# 9130                 False                    False
# 9131                 False                    False
# 9132                 False                    False
# 9133                 False                    False
#
#       months_since_policy_inception  number_of_open_complaints  \
# 0                             False                      False
# 1                             False                      False
# 2                             False                      False
# 3                             False                      False
# ...

# %%
#Did you find outliers? Comment what you will do with them. If you decide to remove them, do that now. Also, remove them from your main dataframe.

# From the outputs above there are outliers in monthly_premium_auto , customer_lifetime_value and in the Target total_claim_amount which all 
# summed up give about 1700 outliers. If we look to the original dataframe customer_df that has 9134 rows, if we were to remove the 
# the outliers that would mean a removal of about 18% of data. That is quite a large sum of data being removed that could actually
# mean something for the model we are trying to predict, so we won't be removing the outliers but dig into a more deep analysis,
# in order to find out what they mean.

# %%
continuous_df.describe()
# Out:
#        customer_lifetime_value        income  total_claim_amount
# count              9134.000000   9134.000000         9134.000000
# mean               8004.940475  37657.380009          434.088794
# std                6870.967608  30379.904734          290.500092
# min                1898.007675      0.000000            0.099007
# 25%                3994.251794      0.000000          272.258244
# 50%                5780.182197  33889.500000          383.945434
# 75%                8962.167041  62320.000000          547.514839
# max               83325.381190  99981.000000         2893.239678

# %%
#IF we decided to remove Null values we would follow the approach below

# %%
# Calculate the interquartile range (IQR) for "customer_lifetime_value"
iqr = np.nanpercentile(continuous_df["customer_lifetime_value"], 75) - np.nanpercentile(continuous_df["customer_lifetime_value"], 25)

# Calculate the upper limit for outliers using the IQR method
upper_limit = np.nanpercentile(continuous_df["customer_lifetime_value"], 75) + 1.5 * iqr

# Print the calculated upper limit
upper_limit

extraordinary_points = continuous_df[continuous_df ["customer_lifetime_value"]>upper_limit]
len(extraordinary_points)
# Out:
# 817

# %%
df_no_outliers_customer_lifetime = continuous_df[continuous_df ["customer_lifetime_value"]<upper_limit]
df_no_outliers_customer_lifetime.describe()
# Out:
#        customer_lifetime_value        income  total_claim_amount
# count              8317.000000   8317.000000         8317.000000
# mean               6279.177892  37638.476855          423.041312
# std                3240.426385  30415.335684          275.674499
# min                1898.007675      0.000000            0.099007
# 25%                3746.751625      0.000000          268.471802
# 50%                5470.060561  33837.000000          374.400000
# 75%                8162.617053  62229.000000          542.400000
# max               16407.664610  99981.000000         2893.239678

# %%
#Check all columns for NaN values. Decide what (if anything) you will need to do with them, do that now.


numerical_df.isnull().sum()
# Out:
# customer_lifetime_value          0
# income                           0
# monthly_premium_auto             0
# months_since_last_claim          0
# months_since_policy_inception    0
# number_of_open_complaints        0
# number_of_policies               0
# total_claim_amount               0
# dtype: int64

# %%
numerical_df.isnull().sum()/len(numerical_df)
# Out:
# customer_lifetime_value          0.0
# income                           0.0
# monthly_premium_auto             0.0
# months_since_last_claim          0.0
# months_since_policy_inception    0.0
# number_of_open_complaints        0.0
# number_of_policies               0.0
# total_claim_amount               0.0
# dtype: float64

# %%
#From the results above there are no Null values, so we don't have to decide what to do with the no existence of them

# %%
14# 
numerical_df.to_csv('numerical.csv')

# %%
numerical_df.to_csv('numerical.csv', index=False)

# %% [markdown]
# # Lab part 2 Cleaning categoricals

# %%
#Find all of the categorical data. Save it in a categorical_df variable.

# %%
categorical_df = customer_df.select_dtypes(object)
categorical_df
# Out:
#      customer       state response  coverage education employmentstatus  \
# 0     BU79786  Washington       No     Basic  Bachelor         Employed
# 1     QZ44356     Arizona       No  Extended  Bachelor       Unemployed
# 2     AI49188      Nevada       No   Premium  Bachelor         Employed
# 3     WW63253  California       No     Basic  Bachelor       Unemployed
# 4     HB64268  Washington       No     Basic  Bachelor         Employed
# ...       ...         ...      ...       ...       ...              ...
# 9129  LA72316  California       No     Basic  Bachelor         Employed
# 9130  PK87824  California      Yes  Extended   College         Employed
# 9131  TD14365  California       No  Extended  Bachelor       Unemployed
# 9132  UP19263  California       No  Extended   College         Employed
# 9133  Y167826  California       No  Extended   College       Unemployed
#
#      gender location_code marital_status     policy_type        policy  \
# ...

# %%
#Check for NaN values and decide what to do with them, do it now

categorical_df.isna().sum()
# Out:
# customer            0
# state               0
# response            0
# coverage            0
# education           0
# employmentstatus    0
# gender              0
# location_code       0
# marital_status      0
# policy_type         0
# policy              0
# renew_offer_type    0
# sales_channel       0
# vehicle_class       0
# vehicle_size        0
# dtype: int64

# %%
#There are no Null Values in the above categorical columns

# %%
#Check dtypes. Do they all make sense as categorical data?

categorical_df.dtypes
# Out:
# customer            object
# state               object
# response            object
# coverage            object
# education           object
# employmentstatus    object
# gender              object
# location_code       object
# marital_status      object
# policy_type         object
# policy              object
# renew_offer_type    object
# sales_channel       object
# vehicle_class       object
# vehicle_size        object
# dtype: object

# %%
#From the result above after the datatypes checked it makes sense to consider them part of categorical data

# %%
categorical_df.nunique()
# Out:
# customer            9134
# state                  5
# response               2
# coverage               3
# education              5
# employmentstatus       5
# gender                 2
# location_code          3
# marital_status         3
# policy_type            3
# policy                 9
# renew_offer_type       4
# sales_channel          4
# vehicle_class          6
# vehicle_size           3
# dtype: int64

# %%
unique_values_per_column = {}

# Iterate through the columns to collect unique values
for column in categorical_df.columns:
    unique_values = categorical_df[column].unique()
    unique_values_per_column[column] = unique_values

# unique values per column
for column, unique_values in unique_values_per_column.items():
    print(f"Unique values in '{column}':")
    print(unique_values)
    print()
# Out:
# Unique values in 'customer':
# ['BU79786' 'QZ44356' 'AI49188' ... 'TD14365' 'UP19263' 'Y167826']
#
# Unique values in 'state':
# ['Washington' 'Arizona' 'Nevada' 'California' 'Oregon']
#
# Unique values in 'response':
# ['No' 'Yes']
#
# Unique values in 'coverage':
# ['Basic' 'Extended' 'Premium']
#
# Unique values in 'education':
# ['Bachelor' 'College' 'Master' 'High School or Below' 'Doctor']
#
# Unique values in 'employmentstatus':
# ['Employed' 'Unemployed' 'Medical Leave' 'Disabled' 'Retired']
#
# Unique values in 'gender':
# ['F' 'M']
#
# Unique values in 'location_code':
# ['Suburban' 'Rural' 'Urban']
#
# Unique values in 'marital_status':
# ['Married' 'Single' 'Divorced']
#
# Unique values in 'policy_type':
# ['Corporate Auto' 'Personal Auto' 'Special Auto']
#
# Unique values in 'policy':
# ['Corporate L3' 'Personal L3' 'Corporate L2' 'Personal L1' 'Special L2'
#  'Corporate L1' 'Personal L2' 'Special L1' 'Special L3']
#
# Unique values in 'renew_offer_type':
# ...

# %%
categorical_df[["policy","renew_offer_type"]]
# Out:
#             policy renew_offer_type
# 0     Corporate L3           Offer1
# 1      Personal L3           Offer3
# 2      Personal L3           Offer1
# 3     Corporate L2           Offer1
# 4      Personal L1           Offer1
# ...            ...              ...
# 9129   Personal L1           Offer2
# 9130  Corporate L3           Offer1
# 9131  Corporate L2           Offer1
# 9132   Personal L2           Offer3
# 9133  Corporate L3           Offer4
#
# [9134 rows x 2 columns]

# %%
# From the outputs above the columns policy, renew_offer_type and customer contain alpha and numeric elements

# %%
# We will not clean customer since it may not so relevant for what we are trying to predict, for that reason not only we will not
# but we will also drop
categorical_df=categorical_df.drop("customer",axis=1)
categorical_df
# Out:
#            state response  coverage education employmentstatus gender  \
# 0     Washington       No     Basic  Bachelor         Employed      F
# 1        Arizona       No  Extended  Bachelor       Unemployed      F
# 2         Nevada       No   Premium  Bachelor         Employed      F
# 3     California       No     Basic  Bachelor       Unemployed      M
# 4     Washington       No     Basic  Bachelor         Employed      M
# ...          ...      ...       ...       ...              ...    ...
# 9129  California       No     Basic  Bachelor         Employed      M
# 9130  California      Yes  Extended   College         Employed      F
# 9131  California       No  Extended  Bachelor       Unemployed      M
# 9132  California       No  Extended   College         Employed      M
# 9133  California       No  Extended   College       Unemployed      M
#
#      location_code marital_status     policy_type        policy  \
# ...

# %%
#6.Does any column contain alpha and numeric data? Decide how to clean it and do it now.

# %%
display(categorical_df['policy'].value_counts(dropna=False))
display(categorical_df['renew_offer_type'].value_counts(dropna=False))
display(categorical_df['policy_type'].value_counts(dropna=False))
# Out:
# Personal L3     3426
# Personal L2     2122
# Personal L1     1240
# Corporate L3    1014
# Corporate L2     595
# Corporate L1     359
# Special L2       164
# Special L3       148
# Special L1        66
# Name: policy, dtype: int64
# Offer1    3752
# Offer2    2926
# Offer3    1432
# Offer4    1024
# Name: renew_offer_type, dtype: int64
# Personal Auto     6788
# Corporate Auto    1968
# Special Auto       378
# Name: policy_type, dtype: int64

# %%
#6.Does any column contain alpha and numeric data? Decide how to clean it and do it now.

# %%
categorical_df['policy'] = categorical_df['policy'].replace(['Personal L3', 'Personal L2', 'Personal L1'], 'Personal')
categorical_df ['policy'].unique()
# Out:
# array(['Corporate L3', 'Personal', 'Corporate L2', 'Special L2',
#        'Corporate L1', 'Special L1', 'Special L3'], dtype=object)

# %%
categorical_df['policy'] = categorical_df['policy'].replace(['Corporate L3', 'Corporate L2', 'Corporate L1'], 'Corporate')
categorical_df ['policy'].unique()
# Out:
# array(['Corporate', 'Personal', 'Special L2', 'Special L1', 'Special L3'],
#       dtype=object)

# %%
categorical_df['policy'] = categorical_df['policy'].replace(['Special L3', 'Special L2', 'Special L1'], 'Special')
categorical_df ['policy'].unique()
# Out:
# array(['Corporate', 'Personal', 'Special'], dtype=object)

# %%
display(categorical_df['policy'].value_counts(dropna=False))
# Out:
# Personal     6788
# Corporate    1968
# Special       378
# Name: policy, dtype: int64

# %%
#Deciding to clean the policy column since we should just have or alpha or numeric elements as values. We will keep just the number
#since they may help us indicate some kind of order or level between them
#categorical_df['policy'] = categorical_df['policy'].str.extract('(\d+)')
#categorical_df

# %%
#display(categorical_df['policy'].value_counts(dropna=False))

# %%
# We will follow a different logic for the column renew_offer_type  by keeping just the number instead of the
#string. Keeping just the number may be sufficient to indicate some kind of distinction between them. The word "Offer" does not
# seem to add meaning to it.


categorical_df['renew_offer_type'] = categorical_df['renew_offer_type'].str.replace('Offer', '', regex=True)
categorical_df
# Out:
#            state response  coverage education employmentstatus gender  \
# 0     Washington       No     Basic  Bachelor         Employed      F
# 1        Arizona       No  Extended  Bachelor       Unemployed      F
# 2         Nevada       No   Premium  Bachelor         Employed      F
# 3     California       No     Basic  Bachelor       Unemployed      M
# 4     Washington       No     Basic  Bachelor         Employed      M
# ...          ...      ...       ...       ...              ...    ...
# 9129  California       No     Basic  Bachelor         Employed      M
# 9130  California      Yes  Extended   College         Employed      F
# 9131  California       No  Extended  Bachelor       Unemployed      M
# 9132  California       No  Extended   College         Employed      M
# 9133  California       No  Extended   College       Unemployed      M
#
#      location_code marital_status     policy_type     policy renew_offer_type  \
# ...

# %%
# Would you choose to do anything else to clean or wrangle the categorical data?

display(categorical_df['vehicle_class'].value_counts(dropna=False))
# Out:
# Four-Door Car    4621
# Two-Door Car     1886
# SUV              1796
# Sports Car        484
# Luxury SUV        184
# Luxury Car        163
# Name: vehicle_class, dtype: int64

# %%
#based on the lower values for Sports Car, Luxury SUV and Luxury Car, and since the ideal is to have if possible short categories
# Let's combine them into one vehicle_class called: Lux_Sport_Car

categorical_df['vehicle_class'] = categorical_df['vehicle_class'].replace(['Luxury SUV', 'Sports Car', 'Luxury Car'], 'Lux_Sport_Car')
categorical_df ['vehicle_class'].unique()
# Out:
# array(['Two-Door Car', 'Four-Door Car', 'SUV', 'Lux_Sport_Car'],
#       dtype=object)

# %%
categorical_df["employmentstatus"] = categorical_df["employmentstatus"].map({"Medical Leave" : 0, "Disabled" : 0, "Unemployed" : 0, "Retired" : .5, "Employed":2})

# %%
display(categorical_df['employmentstatus'].value_counts(dropna=False))
# Out:
# 2.0    5698
# 0.0    3154
# 0.5     282
# Name: employmentstatus, dtype: int64

# %%
categorical_df['education']=categorical_df['education'].map({'High School or Below':0,'Bachelor':.5,'College':.5,'Master':1,'Doctor':1})

# %%
categorical_df['coverage']=categorical_df['coverage'].map({"Basic":0, "Extended":.5, "Premium" : 1})

# %%
categorical_df['vehicle_size']=categorical_df['vehicle_size'].map({"Small":0, "Medsize":.5, "Large" : 1})

# %%
categorical_df['location_code']=categorical_df['location_code'].map({"Rural":0, "Suburban":.5, "Urban" : 1})

# %%
categorical_df['response'] = categorical_df['response'].replace({'No':'0', 'Yes':'1'})

# %%
categorical_df.head()
# Out:
#         state response  coverage  education  employmentstatus gender  \
# 0  Washington        0       0.0        0.5               2.0      F
# 1     Arizona        0       0.5        0.5               0.0      F
# 2      Nevada        0       1.0        0.5               2.0      F
# 3  California        0       0.0        0.5               0.0      M
# 4  Washington        0       0.0        0.5               2.0      M
#
#    location_code marital_status     policy_type     policy renew_offer_type  \
# 0            0.5        Married  Corporate Auto  Corporate                1
# 1            0.5         Single   Personal Auto   Personal                3
# 2            0.5        Married   Personal Auto   Personal                1
# 3            0.5        Married  Corporate Auto  Corporate                1
# 4            0.0         Single   Personal Auto   Personal                1
#
#   sales_channel  vehicle_class  vehicle_size
# 0         Agent   Two-Door Car           0.5
# ...

# %%
#8.Compare policy_type and policy. What information is contained in these columns. Can you identify what is important?

policy_type_count = categorical_df['policy_type'].value_counts()
print(policy_type_count)

policy_counts = categorical_df['policy'].value_counts()
print(policy_counts)
# Out:
# Personal Auto     6788
# Corporate Auto    1968
# Special Auto       378
# Name: policy_type, dtype: int64
# Personal     6788
# Corporate    1968
# Special       378
# Name: policy, dtype: int64

# %%
#Previously by combining the different L's(1,2,3) in policy_type into 3 single categories of Corporate,Special and Personal and now comparing it to
# to policy we find out that columns have the same number of unique values per category which may well mean that these 2 columns are the same
# and we can drop one of the columns

# %%
categorical_df=categorical_df.drop("policy",axis=1)
categorical_df
# Out:
#            state response  coverage  education  employmentstatus gender  \
# 0     Washington        0       0.0        0.5               2.0      F
# 1        Arizona        0       0.5        0.5               0.0      F
# 2         Nevada        0       1.0        0.5               2.0      F
# 3     California        0       0.0        0.5               0.0      M
# 4     Washington        0       0.0        0.5               2.0      M
# ...          ...      ...       ...        ...               ...    ...
# 9129  California        0       0.0        0.5               2.0      M
# 9130  California        1       0.5        0.5               2.0      F
# 9131  California        0       0.5        0.5               0.0      M
# 9132  California        0       0.5        0.5               2.0      M
# 9133  California        0       0.5        0.5               0.0      M
#
#       location_code marital_status     policy_type renew_offer_type  \
# ...

# %%
#9 Check number of unique values in each column, can they be combined in any way to ease encoding? 
#Comment your thoughts and make those changes.

unique_values_per_column = categorical_df.nunique()
for column in categorical_df.columns:
    print(f"{column}: {categorical_df[column].nunique()} unique values")
# Out:
# state: 5 unique values
# response: 2 unique values
# coverage: 3 unique values
# education: 3 unique values
# employmentstatus: 3 unique values
# gender: 2 unique values
# location_code: 3 unique values
# marital_status: 3 unique values
# policy_type: 3 unique values
# renew_offer_type: 4 unique values
# sales_channel: 4 unique values
# vehicle_class: 4 unique values
# vehicle_size: 3 unique values

# %%
# I can comment that personally, all the possible combinations were already performed in the previous exercises. I did consider
#cleaning or combining "emplyoment status" creating 2 groups of Active and non-active  but I look at the target and cannot hold 
#my thoughts that the different categories may help us
# drive interesting conclusions among Employed, Unemployed, Medical leave, Disabled, Retired. Conclusion I will leave it like it is.

# %%
# As we were advised we are adding the "effective_to_date" column to categorical_df
categorical_df['effective_to_date'] = customer_df['effective_to_date']
categorical_df
# Out:
#            state response  coverage  education  employmentstatus gender  \
# 0     Washington        0       0.0        0.5               2.0      F
# 1        Arizona        0       0.5        0.5               0.0      F
# 2         Nevada        0       1.0        0.5               2.0      F
# 3     California        0       0.0        0.5               0.0      M
# 4     Washington        0       0.0        0.5               2.0      M
# ...          ...      ...       ...        ...               ...    ...
# 9129  California        0       0.0        0.5               2.0      M
# 9130  California        1       0.5        0.5               2.0      F
# 9131  California        0       0.5        0.5               0.0      M
# 9132  California        0       0.5        0.5               2.0      M
# 9133  California        0       0.5        0.5               0.0      M
#
#       location_code marital_status     policy_type renew_offer_type  \
# ...

# %%
categorical_df.to_csv('categorical.csv', index=False)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
categorical_df
# Out:
#            state response  coverage  education  employmentstatus gender  \
# 0     Washington        0       0.0        0.5               2.0      F
# 1        Arizona        0       0.5        0.5               0.0      F
# 2         Nevada        0       1.0        0.5               2.0      F
# 3     California        0       0.0        0.5               0.0      M
# 4     Washington        0       0.0        0.5               2.0      M
# ...          ...      ...       ...        ...               ...    ...
# 9129  California        0       0.0        0.5               2.0      M
# 9130  California        1       0.5        0.5               2.0      F
# 9131  California        0       0.5        0.5               0.0      M
# 9132  California        0       0.5        0.5               2.0      M
# 9133  California        0       0.5        0.5               0.0      M
#
#       location_code marital_status     policy_type renew_offer_type  \
# ...

# %%
2#Plot all the categorical variables with the proper plot. What can you see?
# Out:
# 2

# %%
categorical_columns = categorical_df.select_dtypes(include=['category', 'object'])

# Loop through each categorical column and create plots
for column in categorical_columns.columns:
    # Count the frequency of each unique value in the column
    value_counts = categorical_df[column].value_counts()
    
    # Check if the number of unique values is reasonable for plotting
    if len(value_counts) <= 10:
        # If there are 10 or fewer unique values, create a bar plot
        plt.figure(figsize=(8, 6))
        sns.countplot(data=categorical_df, x=column)
        plt.title(f'{column} - Bar Plot')
        plt.xticks(rotation=45)
        plt.show()
    else:
        # If there are more than 10 unique values, create a count plot
        plt.figure(figsize=(8, 6))
        sns.countplot(data=categorical_df, y=column, order=value_counts.index)
        plt.title(f'{column} - Count Plot')
        plt.show()

# %%
3# This exercise was already done previously in the previous outputs 55, 56, 57 , 58, 71
# Out:
# 3

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming you have a DataFrame called categorical_df with a datetime64 column 'effective_to_date'
# First, ensure that 'effective_to_date' is of datetime64 data type
categorical_df['effective_to_date'] = pd.to_datetime(categorical_df['effective_to_date'])

# Sort the DataFrame by 'effective_to_date' for a meaningful time series plot
categorical_df.sort_values(by='effective_to_date', inplace=True)

# Create the time series plot
plt.figure(figsize=(12, 6))
plt.plot(categorical_df['effective_to_date'], categorical_df['effective_to_date'], marker='o', linestyle='-')
plt.title('Time Series Plot of effective_to_date')
plt.xlabel('Effective Date')
plt.ylabel('effective_to_date')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
#This plot does not give us any relevant information

# %%
import pandas as pd

categorical_df['effective_to_date'] = pd.to_datetime(categorical_df['effective_to_date'])

# Extract day, week, and month as integers into separate columns
categorical_df['day'] = categorical_df['effective_to_date'].dt.day
categorical_df['week'] = categorical_df['effective_to_date'].dt.isocalendar().week
categorical_df['month'] = categorical_df['effective_to_date'].dt.month

# Display the modified DataFrame with the new columns
print(categorical_df[['effective_to_date', 'day', 'week', 'month']])
# Out:
#      effective_to_date  day  week  month
# 3451        2011-01-01    1    52      1
# 4044        2011-01-01    1    52      1
# 3993        2011-01-01    1    52      1
# 7846        2011-01-01    1    52      1
# 7847        2011-01-01    1    52      1
# ...                ...  ...   ...    ...
# 461         2011-02-28   28     9      2
# 5756        2011-02-28   28     9      2
# 8679        2011-02-28   28     9      2
# 4191        2011-02-28   28     9      2
# 1476        2011-02-28   28     9      2
#
# [9134 rows x 4 columns]

# %%
categorical_df
# Out:
#            state response  coverage  education  employmentstatus gender  \
# 3451  Washington        1       0.5        0.0               0.0      M
# 4044  California        0       0.0        1.0               2.0      M
# 3993      Nevada        0       0.5        0.5               0.0      F
# 7846      Nevada        0       0.0        0.5               2.0      F
# 7847  Washington        0       0.0        0.5               0.0      F
# ...          ...      ...       ...        ...               ...    ...
# 461   California        0       0.0        0.5               0.0      F
# 5756      Oregon        0       0.0        0.5               0.0      M
# 8679  California        0       0.5        0.0               0.0      M
# 4191  California        0       0.0        0.0               2.0      M
# 1476      Nevada        0       0.0        0.5               0.0      F
#
#       location_code marital_status     policy_type renew_offer_type  \
# ...

# %% [markdown]
# # Lab | Comparing regression models

# %%
column_data_types = categorical_df.dtypes

column_data_types
# Out:
# state                        object
# response                     object
# coverage                    float64
# education                   float64
# employmentstatus            float64
# gender                       object
# location_code               float64
# marital_status               object
# policy_type                  object
# renew_offer_type             object
# sales_channel                object
# vehicle_class                object
# vehicle_size                float64
# effective_to_date    datetime64[ns]
# day                           int64
# week                         UInt32
# month                         int64
# dtype: object

# %%
# Define the data types to drop (datetime64[ns], int64, UInt32)
data_types_to_drop = ['datetime64[ns]', 'int64', 'UInt32']

# Get the columns with the specified data types
columns_to_drop = categorical_df.select_dtypes(include=data_types_to_drop).columns

# Drop the columns
categorical_df = categorical_df.drop(columns=columns_to_drop)
categorical_df
# Out:
#            state response  coverage  education  employmentstatus gender  \
# 3451  Washington        1       0.5        0.0               0.0      M
# 4044  California        0       0.0        1.0               2.0      M
# 3993      Nevada        0       0.5        0.5               0.0      F
# 7846      Nevada        0       0.0        0.5               2.0      F
# 7847  Washington        0       0.0        0.5               0.0      F
# ...          ...      ...       ...        ...               ...    ...
# 461   California        0       0.0        0.5               0.0      F
# 5756      Oregon        0       0.0        0.5               0.0      M
# 8679  California        0       0.5        0.0               0.0      M
# 4191  California        0       0.0        0.0               2.0      M
# 1476      Nevada        0       0.0        0.5               0.0      F
#
#       location_code marital_status     policy_type renew_offer_type  \
# ...

# %%
# Define a list of data types that typically indicate ordinal encoding
ordinal_data_types = ['int64', 'int32']

# Get a list of all column names
all_columns = categorical_df.columns

# Create an empty DataFrame to store non-ordinal encoded columns
not_ord_encoded = pd.DataFrame()

# Loop through columns and check if they are not of ordinal data types
for column_name in all_columns:
    data_type = str(categorical_df[column_name].dtype)
    if data_type not in ordinal_data_types:
        not_ord_encoded[column_name] = categorical_df[column_name]

# Display the DataFrame containing non-ordinal encoded columns
not_ord_encoded
# Out:
#            state response  coverage  education  employmentstatus gender  \
# 3451  Washington        1       0.5        0.0               0.0      M
# 4044  California        0       0.0        1.0               2.0      M
# 3993      Nevada        0       0.5        0.5               0.0      F
# 7846      Nevada        0       0.0        0.5               2.0      F
# 7847  Washington        0       0.0        0.5               0.0      F
# ...          ...      ...       ...        ...               ...    ...
# 461   California        0       0.0        0.5               0.0      F
# 5756      Oregon        0       0.0        0.5               0.0      M
# 8679  California        0       0.5        0.0               0.0      M
# 4191  California        0       0.0        0.0               2.0      M
# 1476      Nevada        0       0.0        0.5               0.0      F
#
#       location_code marital_status     policy_type renew_offer_type  \
# ...

# %%
column_name = 'state'

unique_values = categorical_df[column_name].unique()

# Print the unique values
print("Unique values in the 'state' column:")
print(unique_values)
# Out:
# Unique values in the 'state' column:
# ['Washington' 'California' 'Nevada' 'Arizona' 'Oregon']

# %%
# List of columns to extract
columns_to_extract = ["coverage", "education", "employmentstatus", "location_code", "vehicle_size"]

# Create a new DataFrame 'ordinal_encoded' containing the selected columns
ordinal_encoded = categorical_df[columns_to_extract].copy()

# Now 'ordinal_encoded' contains only the selected columns

# %%
ordinal_encoded
# Out:
#       coverage  education  employmentstatus  location_code  vehicle_size
# 3451       0.5        0.0               0.0            0.5           0.5
# 4044       0.0        1.0               2.0            1.0           0.5
# 3993       0.5        0.5               0.0            0.0           1.0
# 7846       0.0        0.5               2.0            0.5           0.5
# 7847       0.0        0.5               0.0            0.5           0.5
# ...        ...        ...               ...            ...           ...
# 461        0.0        0.5               0.0            0.5           0.5
# 5756       0.0        0.5               0.0            0.5           0.0
# 8679       0.5        0.0               0.0            0.5           0.5
# 4191       0.0        0.0               2.0            0.5           1.0
# 1476       0.0        0.5               0.0            0.5           0.5
#
# [9134 rows x 5 columns]

# %%
# List of columns to extract
columns_to_extract = ["state", "gender", "marital_status", "policy_type", "sales_channel", "vehicle_class", "renew_offer_type"]

# Create a new DataFrame 'need_encoding' containing the selected columns
need_encoding = categorical_df[columns_to_extract].copy()
need_encoding
# Out:
#            state gender marital_status     policy_type sales_channel  \
# 3451  Washington      M         Single   Personal Auto         Agent
# 4044  California      M         Single   Personal Auto   Call Center
# 3993      Nevada      F        Married  Corporate Auto         Agent
# 7846      Nevada      F        Married   Personal Auto         Agent
# 7847  Washington      F         Single   Personal Auto         Agent
# ...          ...    ...            ...             ...           ...
# 461   California      F        Married   Personal Auto           Web
# 5756      Oregon      M         Single  Corporate Auto        Branch
# 8679  California      M       Divorced  Corporate Auto   Call Center
# 4191  California      M        Married   Personal Auto        Branch
# 1476      Nevada      F         Single   Personal Auto         Agent
#
#       vehicle_class renew_offer_type
# 3451   Two-Door Car                1
# 4044  Four-Door Car                1
# ...

# %%
# List of columns to one-hot encode
columns_to_encode = ["state", "gender", "marital_status", "policy_type", "sales_channel", "vehicle_class", "renew_offer_type"]

# Use get_dummies to one-hot encode the specified columns
need_encoding_encoded = pd.get_dummies(need_encoding, columns=columns_to_encode)

# Now 'need_encoding_encoded' contains the one-hot encoded DataFrame

# %%
need_encoding_encoded
# Out:
#       state_Arizona  state_California  state_Nevada  state_Oregon  \
# 3451              0                 0             0             0
# 4044              0                 1             0             0
# 3993              0                 0             1             0
# 7846              0                 0             1             0
# 7847              0                 0             0             0
# ...             ...               ...           ...           ...
# 461               0                 1             0             0
# 5756              0                 0             0             1
# 8679              0                 1             0             0
# 4191              0                 1             0             0
# 1476              0                 0             1             0
#
#       state_Washington  gender_F  gender_M  marital_status_Divorced  \
# 3451                 1         0         1                        0
# ...

# %%
import pandas as pd

# Assuming you have DataFrames need_encoding_encoded and ordinal_encoded
# If not, make sure you have created them as described previously

# Concatenate the two DataFrames horizontally (along columns)
categorical_df_encoded = pd.concat([ordinal_encoded, need_encoding_encoded], axis=1)
categorical_df_encoded
# Out:
#       coverage  education  employmentstatus  location_code  vehicle_size  \
# 3451       0.5        0.0               0.0            0.5           0.5
# 4044       0.0        1.0               2.0            1.0           0.5
# 3993       0.5        0.5               0.0            0.0           1.0
# 7846       0.0        0.5               2.0            0.5           0.5
# 7847       0.0        0.5               0.0            0.5           0.5
# ...        ...        ...               ...            ...           ...
# 461        0.0        0.5               0.0            0.5           0.5
# 5756       0.0        0.5               0.0            0.5           0.0
# 8679       0.5        0.0               0.0            0.5           0.5
# 4191       0.0        0.0               2.0            0.5           1.0
# 1476       0.0        0.5               0.0            0.5           0.5
#
#       state_Arizona  state_California  state_Nevada  state_Oregon  \
# ...

# %%
# Concatenate the two DataFrames horizontally (along columns)
data = pd.concat([numerical_df, categorical_df_encoded], axis=1)
data
# Out:
#       customer_lifetime_value   income  monthly_premium_auto  \
# 0                 2763.519279  56274.0                    69
# 1                 6979.535903      0.0                    94
# 2                12887.431650  48767.0                   108
# 3                 7645.861827      0.0                   106
# 4                 2813.692575  43836.0                    73
# ...                       ...      ...                   ...
# 9129             23405.987980  71941.0                    73
# 9130              3096.511217  21604.0                    79
# 9131              8163.890428      0.0                    85
# 9132              7524.442436  21941.0                    96
# 9133              2611.836866      0.0                    77
#
#       months_since_last_claim  months_since_policy_inception  \
# 0                          32                              5
# 1                          13                             42
# ...

# %%
X = data.drop(['total_claim_amount'],axis=1)
y = data['total_claim_amount']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=100)

# %%
X_train.shape
# Out:
# (7307, 37)

# %%
# Starting the process of splitting both Train and Test in numericals
# Notice that due to the previous encoding before the split my numerical are also my categorical
numerical_df_train = X_train.select_dtypes(np.number)
numerical_df_test = X_test.select_dtypes(np.number)
numerical_df_train.head()
# Out:
#       customer_lifetime_value   income  monthly_premium_auto  \
# 7706              3265.156348  25820.0                    82
# 779              11318.130830  79270.0                    95
# 8189              6274.447705  13662.0                    85
# 1942              4297.189057  66331.0                   107
# 459              10110.778180  15752.0                    90
#
#       months_since_last_claim  months_since_policy_inception  \
# 7706                       10                             69
# 779                        28                             61
# 8189                       29                             37
# 1942                        0                             74
# 459                        27                             37
#
#       number_of_open_complaints  number_of_policies  coverage  education  \
# 7706                          0                   1       0.5        0.5
# 779                           3                   2       0.5        0.0
# ...

# %%
y_train.head()
# Out:
# 7706    393.600000
# 779     456.000000
# 8189    408.000000
# 1942    513.600000
# 459     339.344531
# Name: total_claim_amount, dtype: float64

# %%
from sklearn.preprocessing import StandardScaler

transformer = StandardScaler().fit(numerical_df_train)
numerical_df_train_standardized = transformer.transform(numerical_df_train)
numerical_df_test_standardized = transformer.transform(numerical_df_test)

# %%
pd.DataFrame(numerical_df_train_standardized).head()
# Out:
#          0         1         2         3         4         5         6   \
# 0 -0.689028 -0.385792 -0.325793 -0.503413  0.755270 -0.418947 -0.819325
# 1  0.484415  1.371370  0.050504  1.288859  0.467992  2.880997 -0.401806
# 2 -0.250528 -0.785485 -0.238955  1.388429 -0.393843 -0.418947  0.015713
# 3 -0.538645  0.946002  0.397854 -1.499119  0.934819 -0.418947 -0.819325
# 4  0.308485 -0.716777 -0.094226  1.189288 -0.393843 -0.418947 -0.401806
#
#          7         8         9         10        11        12        13  \
# 0  0.788110  0.270934  0.778580  0.030374  0.168956 -0.476051  1.373267
# 1  0.788110 -1.365195  0.778580  0.030374  0.168956 -0.476051  1.373267
# 2  0.788110 -1.365195 -1.316654  0.030374 -1.712997 -0.476051 -0.728191
# 3  2.311985 -1.365195  0.778580  0.030374  2.050909 -0.476051 -0.728191
# 4  0.788110  0.270934 -1.316654  1.686677  2.050909 -0.476051  1.373267
#
#          14        15       16        17        18        19        20  \
# ...

# %%
pd.DataFrame(numerical_df_test_standardized).head()
# Out:
#          0         1         2         3         4         5         6   \
# 0 -0.419831  0.625669 -0.817873 -1.100837  1.437556  0.681034  1.268270
# 1 -0.453387 -0.536491  0.860988 -1.200407 -1.291587 -0.418947 -0.819325
# 2 -0.364990 -0.120788 -0.731035 -0.403842  1.258007 -0.418947  2.520828
# 3 -0.625609 -0.657438  0.079450 -0.901696 -1.542956 -0.418947 -0.819325
# 4  0.099975  0.498443  0.455746 -1.001266  0.432082 -0.418947  2.103309
#
#          7         8         9         10        11        12        13  \
# 0 -0.735764  0.270934  0.778580  0.030374  0.168956 -0.476051 -0.728191
# 1  0.788110 -1.365195  0.778580 -1.625929  0.168956 -0.476051 -0.728191
# 2 -0.735764 -1.365195  0.778580 -1.625929  2.050909 -0.476051  1.373267
# 3  0.788110  0.270934 -0.792846  0.030374  0.168956 -0.476051  1.373267
# 4  2.311985  0.270934  0.778580 -1.625929  0.168956 -0.476051 -0.728191
#
#          14        15       16        17        18        19        20  \
# ...

# %%
from sklearn.linear_model import LinearRegression

# %%
linear_model = LinearRegression()

# %%
# Train the model with the training data
linear_model.fit(numerical_df_train_standardized, y_train)
# Out:
# LinearRegression()

# %%
# Evaluate the model with the test data
score_linear = linear_model.score(numerical_df_test_standardized, y_test)
score_linear
# Out:
# 0.6104459209286037

# %%
from sklearn.metrics import r2_score
predictions = linear_model.predict(numerical_df_train_standardized)
r2_score(y_train, predictions)
# Out:
# 0.6311546090117193

# %%
from sklearn.metrics import r2_score
predictions_test = linear_model.predict(numerical_df_test_standardized)
r2_score(y_test, predictions_test)
# Out:
# 0.6104459209286037

# %%
y_test[:5]
# Out:
# 7175    312.000000
# 7255    131.262395
# 2846     65.659137
# 1211    666.724937
# 4294     60.151529
# Name: total_claim_amount, dtype: float64

# %%
predictions_test[:5]
# Out:
# array([195.03913192, 471.89069442, 140.81256942, 481.02443957,
#        287.21881942])

# %%
from sklearn.neighbors import KNeighborsRegressor

KNN = KNeighborsRegressor(n_neighbors=3)
KNN.fit(numerical_df_train_standardized,y_train)
# Out:
# KNeighborsRegressor(n_neighbors=3)

# %%
KNN_score = KNN.score(numerical_df_test_standardized, y_test)
KNN_score
# Out:
# 0.5051332661259392

# %%
score_train = KNN.score(numerical_df_train_standardized, y_train)
score_train
# Out:
# 0.7570950213633122

# %%
#wE are verifying overfitting issue here with a difference of 0.5051332661259392 to 0.7570950213633122, which mean that we are not 
#having a good model here.

# %%
predictions = KNN.predict(numerical_df_test_standardized)
predictions
# Out:
# array([ 416.82610233,  600.11102367,  202.29039767, ...,  167.267541  ,
#        1003.882714  ,  345.467151  ])

# %%
y_test
# Out:
# 7175    312.000000
# 7255    131.262395
# 2846     65.659137
# 1211    666.724937
# 4294     60.151529
#            ...
# 6798    114.273025
# 5301    601.983113
# 8093    336.000000
# 5091    856.800000
# 530     259.060862
# Name: total_claim_amount, Length: 1827, dtype: float64

# %%
from sklearn.neural_network import MLPRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

# %%
# 7.Great! Now define a function that takes a list of models and train (and tests) them so we can try a lot of them 
# without repeating code.

# Define the models
models_to_experiment = [
    #linear_model, KNeighborsRegressor(), MLPRegressor(random_state=1, max_iter=1000),
    #DecisionTreeRegressor(), RandomForestRegressor()
]

# Define a function to train and evaluate models
def train_and_evaluate_models(models, X_train, y_train, X_test, y_test):
    scores = []
    for model in models:
        model.fit(numerical_df_train_standardized, y_train)
        y_pred = model.predict(numerical_df_test_standardized)
        score = r2_score(y_test, y_pred)
        scores.append(score)
    return scores

# Call the function and evaluate the models
scores = train_and_evaluate_models(models_to_experiment,numerical_df_train_standardized , y_train,numerical_df_test_standardized , y_test)

# Print the results for each model
for model, score in zip(models_to_experiment, scores):
    model_name = model.__class__.__name__
    print(f'Model: {model_name}, R^2 Score: {score:.4f}')

# %%
# 8.Use the function to check LinearRegressor and KNeighborsRegressor.

models_to_check = [linear_model, KNeighborsRegressor()]

# Define a function to train and evaluate models
def train_and_evaluate_models(models, X_train, y_train, X_test, y_test):
    scores = []
    for model in models:
        model.fit(numerical_df_train_standardized, y_train)
        y_pred = model.predict(numerical_df_test_standardized)
        score = r2_score(y_test, y_pred)
        scores.append(score)
    return scores

# Call the function and evaluate the models
scores = train_and_evaluate_models(models_to_check, numerical_df_train_standardized, y_train, numerical_df_test_standardized, y_test)

# Print the results for each model
for model, score in zip(models_to_check, scores):
    model_name = model.__class__.__name__
    print(f'Model: {model_name}, R^2 Score: {score:.4f}')
# Out:
# Model: LinearRegression, R^2 Score: 0.6104
# Model: KNeighborsRegressor, R^2 Score: 0.5393

# %%
# 9.You can check also the MLPRegressor for this task!
models_to_try = [ MLPRegressor(random_state=1, max_iter=2000)]

# Define a function to train and evaluate models
def train_and_evaluate_models(models, X_train, y_train, X_test, y_test):
    scores = []
    for model in models:
        model.fit(numerical_df_train_standardized, y_train)
        y_pred = model.predict(numerical_df_test_standardized)
        score = r2_score(y_test, y_pred)
        scores.append(score)
    return scores

# Call the function and evaluate the models
scores = train_and_evaluate_models(models_to_try, numerical_df_train_standardized, y_train, numerical_df_test_standardized, y_test)

# Print the results for each model
for model, score in zip(models_to_try, scores):
    model_name = model.__class__.__name__
    print(f'Model: {model_name}, R^2 Score: {score:.4f}')
# Out:
# Model: MLPRegressor, R^2 Score: 0.8235
# C:\Users\Startklar\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (2000) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %%
#10 Comments on the results above 

# A R2 score of 0.8235 for the MLPRegressor means that the model explains approximately 82.35% of the variance in the dependent variable. 
# This is generally considered a good result, as it suggests that the model is doing a decent job of capturing the underlying patterns in the data and making predictions.
# In comparison to the R2 score 0.61 obtained in the Linear Regression MLPRegressor seems to be doing a more decent performance. The 0.61 in Linear Regression is reasonably a good
# model to capture a significant part of hidden patterns but it exists room for improvement may indicated by some unexplained variance.
# An R2 score of 0.5393 for the KNeighborsRegressor model means that the model explains approximately 53.93% of the variance in the dependent variable. 
#This suggests that the KNeighborsRegressor model is capturing a significant portion of the underlying patterns in the data and making some useful predictions, 
#but there is still a substantial amount of unexplained variance.This said the MLPRegressor a type of neural network-based regression model, presents itself as the best option
